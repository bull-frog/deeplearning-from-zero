# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np

# %%
x = np.array([1,2,3,4,5,10,25,50,75])
y = np.array([37.72,68.60,79.72,87.01,89.33,93.55,96.04,97.01,97.38])

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, marker='o', linestyle='solid')
ax.set_xlim(0, 100)
ax.set_xlabel('隠れ層（１層目）のサイズ')
ax.set_ylim(0, 100)
ax.set_ylabel('テストデータの認識精度（1万回繰り返し後）')
# Out:
# Text(0, 0.5, 'テストデータの認識精度（1万回繰り返し後）')
